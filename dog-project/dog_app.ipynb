# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

import tensorflow as tf
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalAveragePooling3D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint

# %%
# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('data/dog_images/train')
valid_files, valid_targets = load_dataset('data/dog_images/valid')
test_files, test_targets = load_dataset('data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %%
import cv2                

import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i, dog in enumerate(np.random.choice(train_files, 12)):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(cv2.imread(dog))

# %%
from IPython.display import Image
Image(train_files[12])

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %%
import cv2                

import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i, human in enumerate(np.random.choice(human_files, 12)):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(cv2.imread(human))

# %%
Image(human_files[1])

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
# %%time
human_files_short = human_files[:100]
dog_files_short = train_files[:100]

human_hits = []
dog_hits = []

for i in range(100):
    human_hits.append(face_detector(human_files_short[i]))
    dog_hits.append(face_detector(dog_files_short[i]))
    
print(f'Detected correctly {100* (float(np.asarray(human_hits).sum()) / 100)} % of real human faces')
print(f'Detected incorrectly {100* (float(np.asarray(dog_hits).sum() / 100))}% of dogs as human faces')
# Out:
# Detected correctly 100.0 % of real human faces
# Detected incorrectly 12.0% of dogs as human faces
# CPU times: user 49 s, sys: 405 ms, total: 49.4 s
# Wall time: 7.3 s

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
# %%time
human_files_short = human_files[:100]
dog_files_short = train_files[:100]

human_hits = []
dog_hits = []

for i in range(100):
    human_hits.append(dog_detector(human_files_short[i]))
    dog_hits.append(dog_detector(dog_files_short[i]))

print(f'Detected correctly {100* (float(np.asarray(dog_hits).sum() / 100))}% of dogs')
print(f'Detected incorrectly {100* (float(np.asarray(human_hits).sum()) / 100)} % of humans as dogs')
# Out:
# Detected correctly 100.0% of dogs
# Detected incorrectly 0.0 % of humans as dogs
# CPU times: user 1min 7s, sys: 12.7 s, total: 1min 20s
# Wall time: 23.8 s

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:46<00:00, 143.10it/s]
# 100%|██████████| 835/835 [00:05<00:00, 152.78it/s]
# 100%|██████████| 836/836 [00:05<00:00, 146.09it/s]

# %% [markdown]
# ###  Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
input_shape = train_tensors.shape[1], train_tensors.shape[2], train_tensors.shape[3]
input_shape
# Out:
# (224, 224, 3)

# %%
# %%time
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(len(dog_names), activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 500)               25088500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 25,165,677
# Trainable params: 25,165,677
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 354 ms, sys: 756 ms, total: 1.11 s
# Wall time: 212 ms

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  
    height_shift_range=0.1,  
    horizontal_flip=True)

# fit augmented image generator on data
datagen_train.fit(train_tensors)

# %%
# %%time
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 30
batch_size = 64

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(datagen_train.flow(train_tensors, train_targets, batch_size=batch_size),
          steps_per_epoch=train_tensors.shape[0] // batch_size,
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer], verbose=2)
# Out:
# Epoch 1/30
# 104/104 - 186s - loss: 2.5825 - accuracy: 0.3502 - val_loss: 4.0214 - val_accuracy: 0.1772
#
# Epoch 00001: val_loss improved from inf to 4.02145, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/30
# 104/104 - 205s - loss: 2.5857 - accuracy: 0.3482 - val_loss: 4.6790 - val_accuracy: 0.1796
#
# Epoch 00002: val_loss did not improve from 4.02145
# Epoch 3/30
# 104/104 - 219s - loss: 2.5806 - accuracy: 0.3566 - val_loss: 3.8267 - val_accuracy: 0.1533
#
# Epoch 00003: val_loss improved from 4.02145 to 3.82673, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/30
# 104/104 - 211s - loss: 2.6277 - accuracy: 0.3387 - val_loss: 3.9764 - val_accuracy: 0.1401
#
# Epoch 00004: val_loss did not improve from 3.82673
# Epoch 5/30
# 104/104 - 207s - loss: 2.5433 - accuracy: 0.3581 - val_loss: 4.0858 - val_accuracy: 0.1784
#
# Epoch 00005: val_loss did not improve from 3.82673
# Epoch 6/30
# 104/104 - 205s - loss: 2.5700 - accuracy: 0.3569 - val_loss: 4.0243 - val_accuracy: 0.1413
#
# Epoch 00006: val_loss did not improve from 3.82673
# Epoch 7/30
# 104/104 - 218s - loss: 2.5364 - accuracy: 0.3650 - val_loss: 3.9006 - val_accuracy: 0.1497
#
# Epoch 00007: val_loss did not improve from 3.82673
# Epoch 8/30
# 104/104 - 209s - loss: 2.5610 - accuracy: 0.3676 - val_loss: 4.3106 - val_accuracy: 0.1653
#
# Epoch 00008: val_loss did not improve from 3.82673
# Epoch 9/30
# 104/104 - 211s - loss: 2.5982 - accuracy: 0.3517 - val_loss: 3.9640 - val_accuracy: 0.1533
#
# Epoch 00009: val_loss did not improve from 3.82673
# Epoch 10/30
# 104/104 - 219s - loss: 2.5800 - accuracy: 0.3572 - val_loss: 4.6324 - val_accuracy: 0.1557
#
# Epoch 00010: val_loss did not improve from 3.82673
# Epoch 11/30
# 104/104 - 205s - loss: 2.5257 - accuracy: 0.3685 - val_loss: 4.0778 - val_accuracy: 0.1665
#
# Epoch 00011: val_loss did not improve from 3.82673
# Epoch 12/30
# 104/104 - 211s - loss: 2.5486 - accuracy: 0.3641 - val_loss: 3.8671 - val_accuracy: 0.1533
#
# Epoch 00012: val_loss did not improve from 3.82673
# Epoch 13/30
# 104/104 - 213s - loss: 2.5701 - accuracy: 0.3588 - val_loss: 4.1457 - val_accuracy: 0.1629
#
# Epoch 00013: val_loss did not improve from 3.82673
# Epoch 14/30
# 104/104 - 211s - loss: 2.5352 - accuracy: 0.3609 - val_loss: 4.1827 - val_accuracy: 0.1689
#
# Epoch 00014: val_loss did not improve from 3.82673
# Epoch 15/30
# 104/104 - 206s - loss: 2.5578 - accuracy: 0.3676 - val_loss: 4.0670 - val_accuracy: 0.1820
#
# Epoch 00015: val_loss did not improve from 3.82673
# Epoch 16/30
# 104/104 - 206s - loss: 2.5815 - accuracy: 0.3554 - val_loss: 4.2445 - val_accuracy: 0.1772
#
# Epoch 00016: val_loss did not improve from 3.82673
# Epoch 17/30
# 104/104 - 212s - loss: 2.5603 - accuracy: 0.3608 - val_loss: 3.8672 - val_accuracy: 0.1545
#
# Epoch 00017: val_loss did not improve from 3.82673
# Epoch 18/30
# 104/104 - 217s - loss: 2.5550 - accuracy: 0.3664 - val_loss: 3.8026 - val_accuracy: 0.1545
#
# Epoch 00018: val_loss improved from 3.82673 to 3.80265, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 19/30
# 104/104 - 210s - loss: 2.5073 - accuracy: 0.3786 - val_loss: 4.2200 - val_accuracy: 0.1749
#
# Epoch 00019: val_loss did not improve from 3.80265
# Epoch 20/30
# 104/104 - 207s - loss: 2.5598 - accuracy: 0.3670 - val_loss: 4.2292 - val_accuracy: 0.1641
#
# Epoch 00020: val_loss did not improve from 3.80265
# Epoch 21/30
# 104/104 - 209s - loss: 2.5510 - accuracy: 0.3673 - val_loss: 4.3698 - val_accuracy: 0.1665
#
# Epoch 00021: val_loss did not improve from 3.80265
# Epoch 22/30
# 104/104 - 209s - loss: 2.5744 - accuracy: 0.3619 - val_loss: 4.3543 - val_accuracy: 0.1796
#
# Epoch 00022: val_loss did not improve from 3.80265
# Epoch 23/30
# 104/104 - 204s - loss: 2.5521 - accuracy: 0.3671 - val_loss: 4.5856 - val_accuracy: 0.1760
#
# Epoch 00023: val_loss did not improve from 3.80265
# Epoch 24/30
# 104/104 - 163s - loss: 2.5446 - accuracy: 0.3694 - val_loss: 4.7226 - val_accuracy: 0.1689
#
# Epoch 00024: val_loss did not improve from 3.80265
# Epoch 25/30
# 104/104 - 128s - loss: 2.5615 - accuracy: 0.3690 - val_loss: 3.9318 - val_accuracy: 0.1617
#
# Epoch 00025: val_loss did not improve from 3.80265
# Epoch 26/30
# 104/104 - 131s - loss: 2.5429 - accuracy: 0.3665 - val_loss: 4.0359 - val_accuracy: 0.1593
#
# Epoch 00026: val_loss did not improve from 3.80265
# Epoch 27/30
# 104/104 - 129s - loss: 2.5261 - accuracy: 0.3690 - val_loss: 4.1392 - val_accuracy: 0.1701
#
# Epoch 00027: val_loss did not improve from 3.80265
# Epoch 28/30
# 104/104 - 130s - loss: 2.5708 - accuracy: 0.3721 - val_loss: 4.2361 - val_accuracy: 0.1737
#
# Epoch 00028: val_loss did not improve from 3.80265
# Epoch 29/30
# 104/104 - 131s - loss: 2.5215 - accuracy: 0.3706 - val_loss: 4.0539 - val_accuracy: 0.1772
#
# Epoch 00029: val_loss did not improve from 3.80265
# Epoch 30/30
# 104/104 - 125s - loss: 2.5305 - accuracy: 0.3702 - val_loss: 4.6063 - val_accuracy: 0.1629
#
# Epoch 00030: val_loss did not improve from 3.80265
# CPU times: user 8h 15min 5s, sys: 31min 4s, total: 8h 46min 9s
# Wall time: 1h 35min 50s

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 16.3876%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
# %%time

VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: user 16.8 ms, sys: 2.49 ms, total: 19.3 ms
# Wall time: 17.5 ms

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/20
# 334/334 [==============================] - 1s 2ms/step - loss: 12.6466 - accuracy: 0.1069 - val_loss: 3.6996 - val_accuracy: 0.4311
#
# Epoch 00001: val_loss improved from inf to 3.69962, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 2/20
# 334/334 [==============================] - 1s 2ms/step - loss: 2.3091 - accuracy: 0.5795 - val_loss: 2.4321 - val_accuracy: 0.5749
#
# Epoch 00002: val_loss improved from 3.69962 to 2.43210, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 3/20
# 334/334 [==============================] - 1s 2ms/step - loss: 1.1879 - accuracy: 0.7359 - val_loss: 2.1331 - val_accuracy: 0.6347
#
# Epoch 00003: val_loss improved from 2.43210 to 2.13310, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 4/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.7495 - accuracy: 0.8230 - val_loss: 1.9166 - val_accuracy: 0.6719
#
# Epoch 00004: val_loss improved from 2.13310 to 1.91662, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 5/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5006 - accuracy: 0.8716 - val_loss: 1.8999 - val_accuracy: 0.7018
#
# Epoch 00005: val_loss improved from 1.91662 to 1.89992, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 6/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.3839 - accuracy: 0.8947 - val_loss: 1.8413 - val_accuracy: 0.7042
#
# Epoch 00006: val_loss improved from 1.89992 to 1.84127, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 7/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.9260 - val_loss: 1.9078 - val_accuracy: 0.6934
#
# Epoch 00007: val_loss did not improve from 1.84127
# Epoch 8/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.1914 - accuracy: 0.9417 - val_loss: 1.9066 - val_accuracy: 0.7114
#
# Epoch 00008: val_loss did not improve from 1.84127
# Epoch 9/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.1453 - accuracy: 0.9559 - val_loss: 1.7746 - val_accuracy: 0.7317
#
# Epoch 00009: val_loss improved from 1.84127 to 1.77461, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 10/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.1132 - accuracy: 0.9662 - val_loss: 1.8676 - val_accuracy: 0.7437
#
# Epoch 00010: val_loss did not improve from 1.77461
# Epoch 11/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0732 - accuracy: 0.9797 - val_loss: 1.8770 - val_accuracy: 0.7425
#
# Epoch 00011: val_loss did not improve from 1.77461
# Epoch 12/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0663 - accuracy: 0.9806 - val_loss: 1.8473 - val_accuracy: 0.7305
#
# Epoch 00012: val_loss did not improve from 1.77461
# Epoch 13/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0471 - accuracy: 0.9851 - val_loss: 1.9164 - val_accuracy: 0.7497
#
# Epoch 00013: val_loss did not improve from 1.77461
# Epoch 14/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0444 - accuracy: 0.9880 - val_loss: 1.9481 - val_accuracy: 0.7485
#
# Epoch 00014: val_loss did not improve from 1.77461
# Epoch 15/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0393 - accuracy: 0.9896 - val_loss: 1.9665 - val_accuracy: 0.7569
#
# Epoch 00015: val_loss did not improve from 1.77461
# Epoch 16/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0367 - accuracy: 0.9906 - val_loss: 2.1174 - val_accuracy: 0.7210
#
# Epoch 00016: val_loss did not improve from 1.77461
# Epoch 17/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 2.0915 - val_accuracy: 0.7437
#
# Epoch 00017: val_loss did not improve from 1.77461
# Epoch 18/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 2.0447 - val_accuracy: 0.7449
#
# Epoch 00018: val_loss did not improve from 1.77461
# Epoch 19/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 2.1715 - val_accuracy: 0.7377
#
# Epoch 00019: val_loss did not improve from 1.77461
# Epoch 20/20
# 334/334 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 2.2239 - val_accuracy: 0.7341
#
# Epoch 00020: val_loss did not improve from 1.77461

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 72.8469%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.

# %% [markdown]
# ### Pick the best pre-computed network
#
# Evaluate test accuracy of all pre-computed networks and pick the best one to be tunned further. To speed up this process, I will use few epochs and smaller batch sizes.

# %%
NETWORKS = ['VGG19', 'Resnet50', 'InceptionV3', 'Xception']
evaluation_results = {}

def evaluate_pre_computed_network(network: str):
    print(f'\nEvaluating {network}')
    print(f'----------------------------------------------------------------')
        
    bottleneck_features = np.load(f'bottleneck_features/Dog{network}Data.npz')
    train = bottleneck_features['train']
    validation = bottleneck_features['valid']
    test = bottleneck_features['test']
    
    model = Sequential()
    model.add(GlobalAveragePooling2D(input_shape=train.shape[1:]))
    model.add(Dense(133, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

    checkpointer = ModelCheckpoint(filepath=f'saved_models/evaluation/weights.best.{network}.hdf5', 
                               verbose=1, save_best_only=True)

    model.fit(train, train_targets, 
          validation_data=(validation, valid_targets),
          epochs=40, batch_size=512, callbacks=[checkpointer], verbose=0, shuffle=True)
    
    predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) for feature in test]
    test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)
    
    print('Test accuracy: %.4f%%' % test_accuracy)

    return test_accuracy

# %%
# %%time
for network in NETWORKS:
    evaluation_results[network] = evaluate_pre_computed_network(network)
# Out:
# Evaluating VGG19
# ----------------------------------------------------------------
#
# Epoch 00001: val_loss improved from inf to 10.20335, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00002: val_loss improved from 10.20335 to 6.75878, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00003: val_loss improved from 6.75878 to 4.89502, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00004: val_loss improved from 4.89502 to 3.82107, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00005: val_loss improved from 3.82107 to 3.29241, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00006: val_loss improved from 3.29241 to 3.09408, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00007: val_loss improved from 3.09408 to 2.50911, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00008: val_loss improved from 2.50911 to 2.45637, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00009: val_loss improved from 2.45637 to 2.24141, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00010: val_loss improved from 2.24141 to 2.15415, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00011: val_loss improved from 2.15415 to 2.08637, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00012: val_loss improved from 2.08637 to 1.93177, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00013: val_loss improved from 1.93177 to 1.86223, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00014: val_loss did not improve from 1.86223
#
# Epoch 00015: val_loss improved from 1.86223 to 1.75318, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00016: val_loss improved from 1.75318 to 1.74622, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00017: val_loss improved from 1.74622 to 1.71651, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00018: val_loss did not improve from 1.71651
#
# Epoch 00019: val_loss improved from 1.71651 to 1.63431, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00020: val_loss did not improve from 1.63431
#
# Epoch 00021: val_loss improved from 1.63431 to 1.50692, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00022: val_loss did not improve from 1.50692
#
# Epoch 00023: val_loss did not improve from 1.50692
#
# Epoch 00024: val_loss improved from 1.50692 to 1.49553, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00025: val_loss did not improve from 1.49553
#
# Epoch 00026: val_loss did not improve from 1.49553
#
# Epoch 00027: val_loss did not improve from 1.49553
#
# Epoch 00028: val_loss did not improve from 1.49553
#
# Epoch 00029: val_loss did not improve from 1.49553
#
# Epoch 00030: val_loss did not improve from 1.49553
#
# Epoch 00031: val_loss did not improve from 1.49553
#
# Epoch 00032: val_loss did not improve from 1.49553
#
# Epoch 00033: val_loss did not improve from 1.49553
#
# Epoch 00034: val_loss did not improve from 1.49553
#
# Epoch 00035: val_loss did not improve from 1.49553
#
# Epoch 00036: val_loss improved from 1.49553 to 1.48415, saving model to saved_models/evaluation/weights.best.VGG19.hdf5
#
# Epoch 00037: val_loss did not improve from 1.48415
#
# Epoch 00038: val_loss did not improve from 1.48415
#
# Epoch 00039: val_loss did not improve from 1.48415
#
# Epoch 00040: val_loss did not improve from 1.48415
# Test accuracy: 71.8900%
#
# Evaluating Resnet50
# ----------------------------------------------------------------
#
# Epoch 00001: val_loss improved from inf to 2.58265, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00002: val_loss improved from 2.58265 to 1.69667, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00003: val_loss improved from 1.69667 to 1.25530, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00004: val_loss improved from 1.25530 to 1.06957, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00005: val_loss improved from 1.06957 to 0.99798, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00006: val_loss improved from 0.99798 to 0.83011, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00007: val_loss improved from 0.83011 to 0.78701, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00008: val_loss improved from 0.78701 to 0.70379, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00009: val_loss did not improve from 0.70379
#
# Epoch 00010: val_loss improved from 0.70379 to 0.67160, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00011: val_loss did not improve from 0.67160
#
# Epoch 00012: val_loss did not improve from 0.67160
#
# Epoch 00013: val_loss improved from 0.67160 to 0.65918, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00014: val_loss improved from 0.65918 to 0.63964, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00015: val_loss improved from 0.63964 to 0.59112, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00016: val_loss did not improve from 0.59112
#
# Epoch 00017: val_loss did not improve from 0.59112
#
# Epoch 00018: val_loss did not improve from 0.59112
#
# Epoch 00019: val_loss did not improve from 0.59112
#
# Epoch 00020: val_loss improved from 0.59112 to 0.57824, saving model to saved_models/evaluation/weights.best.Resnet50.hdf5
#
# Epoch 00021: val_loss did not improve from 0.57824
#
# Epoch 00022: val_loss did not improve from 0.57824
#
# Epoch 00023: val_loss did not improve from 0.57824
#
# Epoch 00024: val_loss did not improve from 0.57824
#
# Epoch 00025: val_loss did not improve from 0.57824
#
# Epoch 00026: val_loss did not improve from 0.57824
#
# Epoch 00027: val_loss did not improve from 0.57824
#
# Epoch 00028: val_loss did not improve from 0.57824
#
# Epoch 00029: val_loss did not improve from 0.57824
#
# Epoch 00030: val_loss did not improve from 0.57824
#
# Epoch 00031: val_loss did not improve from 0.57824
#
# Epoch 00032: val_loss did not improve from 0.57824
#
# Epoch 00033: val_loss did not improve from 0.57824
#
# Epoch 00034: val_loss did not improve from 0.57824
#
# Epoch 00035: val_loss did not improve from 0.57824
#
# Epoch 00036: val_loss did not improve from 0.57824
#
# Epoch 00037: val_loss did not improve from 0.57824
#
# Epoch 00038: val_loss did not improve from 0.57824
#
# Epoch 00039: val_loss did not improve from 0.57824
#
# Epoch 00040: val_loss did not improve from 0.57824
# Test accuracy: 81.9378%
#
# Evaluating InceptionV3
# ----------------------------------------------------------------
#
# Epoch 00001: val_loss improved from inf to 1.47272, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00002: val_loss improved from 1.47272 to 0.96855, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00003: val_loss improved from 0.96855 to 0.76946, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00004: val_loss improved from 0.76946 to 0.70660, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00005: val_loss improved from 0.70660 to 0.61285, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00006: val_loss improved from 0.61285 to 0.56292, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00007: val_loss did not improve from 0.56292
#
# Epoch 00008: val_loss did not improve from 0.56292
#
# Epoch 00009: val_loss did not improve from 0.56292
#
# Epoch 00010: val_loss improved from 0.56292 to 0.54972, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00011: val_loss did not improve from 0.54972
#
# Epoch 00012: val_loss did not improve from 0.54972
#
# Epoch 00013: val_loss did not improve from 0.54972
#
# Epoch 00014: val_loss did not improve from 0.54972
#
# Epoch 00015: val_loss did not improve from 0.54972
#
# Epoch 00016: val_loss did not improve from 0.54972
#
# Epoch 00017: val_loss did not improve from 0.54972
#
# Epoch 00018: val_loss did not improve from 0.54972
# Epoch 00019: val_loss improved from 0.54972 to 0.53592, saving model to saved_models/evaluation/weights.best.InceptionV3.hdf5
#
# Epoch 00020: val_loss did not improve from 0.53592
#
# Epoch 00021: val_loss did not improve from 0.53592
#
# Epoch 00022: val_loss did not improve from 0.53592
#
# Epoch 00023: val_loss did not improve from 0.53592
#
# Epoch 00024: val_loss did not improve from 0.53592
#
# Epoch 00025: val_loss did not improve from 0.53592
#
# Epoch 00026: val_loss did not improve from 0.53592
#
# Epoch 00027: val_loss did not improve from 0.53592
#
# Epoch 00028: val_loss did not improve from 0.53592
#
# Epoch 00029: val_loss did not improve from 0.53592
#
# Epoch 00030: val_loss did not improve from 0.53592
#
# Epoch 00031: val_loss did not improve from 0.53592
#
# Epoch 00032: val_loss did not improve from 0.53592
#
# Epoch 00033: val_loss did not improve from 0.53592
#
# Epoch 00034: val_loss did not improve from 0.53592
#
# Epoch 00035: val_loss did not improve from 0.53592
#
# Epoch 00036: val_loss did not improve from 0.53592
#
# Epoch 00037: val_loss did not improve from 0.53592
#
# Epoch 00038: val_loss did not improve from 0.53592
#
# Epoch 00039: val_loss did not improve from 0.53592
#
# Epoch 00040: val_loss did not improve from 0.53592
# Test accuracy: 82.2967%
#
# Evaluating Xception
# ----------------------------------------------------------------
#
# Epoch 00001: val_loss improved from inf to 1.44473, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00002: val_loss improved from 1.44473 to 0.88434, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00003: val_loss improved from 0.88434 to 0.69358, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00004: val_loss improved from 0.69358 to 0.59978, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00005: val_loss improved from 0.59978 to 0.54189, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00006: val_loss improved from 0.54189 to 0.51616, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00007: val_loss improved from 0.51616 to 0.49464, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00008: val_loss improved from 0.49464 to 0.46227, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00009: val_loss did not improve from 0.46227
#
# Epoch 00010: val_loss improved from 0.46227 to 0.44094, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00011: val_loss improved from 0.44094 to 0.43489, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00012: val_loss did not improve from 0.43489
#
# Epoch 00013: val_loss did not improve from 0.43489
#
# Epoch 00014: val_loss did not improve from 0.43489
#
# Epoch 00015: val_loss improved from 0.43489 to 0.42896, saving model to saved_models/evaluation/weights.best.Xception.hdf5
#
# Epoch 00016: val_loss did not improve from 0.42896
#
# Epoch 00017: val_loss did not improve from 0.42896
#
# Epoch 00018: val_loss did not improve from 0.42896
#
# Epoch 00019: val_loss did not improve from 0.42896
#
# Epoch 00020: val_loss did not improve from 0.42896
#
# Epoch 00021: val_loss did not improve from 0.42896
#
# Epoch 00022: val_loss did not improve from 0.42896
#
# Epoch 00023: val_loss did not improve from 0.42896
#
# Epoch 00024: val_loss did not improve from 0.42896
#
# Epoch 00025: val_loss did not improve from 0.42896
#
# Epoch 00026: val_loss did not improve from 0.42896
#
# Epoch 00027: val_loss did not improve from 0.42896
#
# Epoch 00028: val_loss did not improve from 0.42896
#
# Epoch 00029: val_loss did not improve from 0.42896
#
# Epoch 00030: val_loss did not improve from 0.42896
#
# Epoch 00031: val_loss did not improve from 0.42896
#
# Epoch 00032: val_loss did not improve from 0.42896
#
# Epoch 00033: val_loss did not improve from 0.42896
#
# Epoch 00034: val_loss did not improve from 0.42896
#
# Epoch 00035: val_loss did not improve from 0.42896
#
# Epoch 00036: val_loss did not improve from 0.42896
#
# Epoch 00037: val_loss did not improve from 0.42896
#
# Epoch 00038: val_loss did not improve from 0.42896
#
# Epoch 00039: val_loss did not improve from 0.42896
#
# Epoch 00040: val_loss did not improve from 0.42896
# Test accuracy: 86.3636%
# CPU times: user 6min 56s, sys: 42.3 s, total: 7min 38s
# Wall time: 2min 51s

# %%
for network in NETWORKS:
    print(f'[{network}] Test accuracy: {round(evaluation_results[network], 4)} %')
# Out:
# [VGG19] Test accuracy: 71.89 %
# [Resnet50] Test accuracy: 81.9378 %
# [InceptionV3] Test accuracy: 82.2967 %
# [Xception] Test accuracy: 86.3636 %

# %% [markdown]
# Based on this previous evaluation, **Xception** had the better performance. Then, I will use this network to try out further improvements.

# %% [markdown]
# ### Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
bottleneck_features = np.load('bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
def create_model():
    Xception_model = Sequential()

    Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))
    Xception_model.add(Dropout(0.1))
    Xception_model.add(Dense(len(dog_names), activation='softmax'))
    
    return Xception_model

Xception_model = create_model()
Xception_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
Xception_model.compile(loss='categorical_crossentropy', 
                       optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
# %%time

batch_size = 512
epochs = 60

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', 
                               verbose=1, save_best_only=True)
    
Xception_model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=epochs, batch_size=batch_size, callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Epoch 1/60
# 14/14 [==============================] - 2s 80ms/step - loss: 4.2071 - accuracy: 0.2018 - val_loss: 2.0624 - val_accuracy: 0.7054
#
# Epoch 00001: val_loss improved from inf to 2.06237, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 2/60
# 14/14 [==============================] - 1s 62ms/step - loss: 1.6511 - accuracy: 0.7502 - val_loss: 0.9619 - val_accuracy: 0.7976
#
# Epoch 00002: val_loss improved from 2.06237 to 0.96189, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 3/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.8066 - accuracy: 0.8378 - val_loss: 0.6911 - val_accuracy: 0.8287
#
# Epoch 00003: val_loss improved from 0.96189 to 0.69113, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 4/60
# 14/14 [==============================] - 1s 66ms/step - loss: 0.5867 - accuracy: 0.8689 - val_loss: 0.6029 - val_accuracy: 0.8407
#
# Epoch 00004: val_loss improved from 0.69113 to 0.60286, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 5/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.4839 - accuracy: 0.8907 - val_loss: 0.5545 - val_accuracy: 0.8395
#
# Epoch 00005: val_loss improved from 0.60286 to 0.55453, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 6/60
# 14/14 [==============================] - 1s 64ms/step - loss: 0.4130 - accuracy: 0.9032 - val_loss: 0.5224 - val_accuracy: 0.8455
#
# Epoch 00006: val_loss improved from 0.55453 to 0.52245, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 7/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.3851 - accuracy: 0.9080 - val_loss: 0.5044 - val_accuracy: 0.8491
#
# Epoch 00007: val_loss improved from 0.52245 to 0.50436, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 8/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.3425 - accuracy: 0.9170 - val_loss: 0.4888 - val_accuracy: 0.8503
#
# Epoch 00008: val_loss improved from 0.50436 to 0.48884, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 9/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.3177 - accuracy: 0.9230 - val_loss: 0.4781 - val_accuracy: 0.8503
#
# Epoch 00009: val_loss improved from 0.48884 to 0.47808, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 10/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.2918 - accuracy: 0.9353 - val_loss: 0.4624 - val_accuracy: 0.8563
#
# Epoch 00010: val_loss improved from 0.47808 to 0.46236, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 11/60
# 14/14 [==============================] - 1s 70ms/step - loss: 0.2743 - accuracy: 0.9369 - val_loss: 0.4616 - val_accuracy: 0.8599
#
# Epoch 00011: val_loss improved from 0.46236 to 0.46157, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 12/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.2536 - accuracy: 0.9402 - val_loss: 0.4552 - val_accuracy: 0.8563
#
# Epoch 00012: val_loss improved from 0.46157 to 0.45515, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 13/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.2348 - accuracy: 0.9498 - val_loss: 0.4491 - val_accuracy: 0.8575
#
# Epoch 00013: val_loss improved from 0.45515 to 0.44914, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 14/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.2283 - accuracy: 0.9501 - val_loss: 0.4410 - val_accuracy: 0.8635
#
# Epoch 00014: val_loss improved from 0.44914 to 0.44101, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 15/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.2129 - accuracy: 0.9568 - val_loss: 0.4419 - val_accuracy: 0.8599
#
# Epoch 00015: val_loss did not improve from 0.44101
# Epoch 16/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.1978 - accuracy: 0.9609 - val_loss: 0.4391 - val_accuracy: 0.8575
#
# Epoch 00016: val_loss improved from 0.44101 to 0.43912, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 17/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.1902 - accuracy: 0.9615 - val_loss: 0.4371 - val_accuracy: 0.8563
#
# Epoch 00017: val_loss improved from 0.43912 to 0.43706, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 18/60
# 14/14 [==============================] - 1s 65ms/step - loss: 0.1763 - accuracy: 0.9669 - val_loss: 0.4289 - val_accuracy: 0.8635
#
# Epoch 00018: val_loss improved from 0.43706 to 0.42888, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 19/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.1692 - accuracy: 0.9691 - val_loss: 0.4313 - val_accuracy: 0.8563
#
# Epoch 00019: val_loss did not improve from 0.42888
# Epoch 20/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.1532 - accuracy: 0.9747 - val_loss: 0.4289 - val_accuracy: 0.8611
#
# Epoch 00020: val_loss did not improve from 0.42888
# Epoch 21/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.1512 - accuracy: 0.9740 - val_loss: 0.4319 - val_accuracy: 0.8635
#
# Epoch 00021: val_loss did not improve from 0.42888
# Epoch 22/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.1457 - accuracy: 0.9767 - val_loss: 0.4304 - val_accuracy: 0.8587
#
# Epoch 00022: val_loss did not improve from 0.42888
# Epoch 23/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.1355 - accuracy: 0.9807 - val_loss: 0.4255 - val_accuracy: 0.8575
#
# Epoch 00023: val_loss improved from 0.42888 to 0.42545, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 24/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.1268 - accuracy: 0.9845 - val_loss: 0.4270 - val_accuracy: 0.8635
#
# Epoch 00024: val_loss did not improve from 0.42545
# Epoch 25/60
# 14/14 [==============================] - 1s 68ms/step - loss: 0.1252 - accuracy: 0.9814 - val_loss: 0.4286 - val_accuracy: 0.8611
#
# Epoch 00025: val_loss did not improve from 0.42545
# Epoch 26/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.1230 - accuracy: 0.9836 - val_loss: 0.4314 - val_accuracy: 0.8599
#
# Epoch 00026: val_loss did not improve from 0.42545
# Epoch 27/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.1154 - accuracy: 0.9840 - val_loss: 0.4239 - val_accuracy: 0.8659
#
# Epoch 00027: val_loss improved from 0.42545 to 0.42385, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 28/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.1137 - accuracy: 0.9832 - val_loss: 0.4241 - val_accuracy: 0.8647
#
# Epoch 00028: val_loss did not improve from 0.42385
# Epoch 29/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.1087 - accuracy: 0.9857 - val_loss: 0.4229 - val_accuracy: 0.8647
#
# Epoch 00029: val_loss improved from 0.42385 to 0.42289, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 30/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.1045 - accuracy: 0.9876 - val_loss: 0.4297 - val_accuracy: 0.8611
#
# Epoch 00030: val_loss did not improve from 0.42289
# Epoch 31/60
# 14/14 [==============================] - 1s 64ms/step - loss: 0.1014 - accuracy: 0.9852 - val_loss: 0.4275 - val_accuracy: 0.8599
#
# Epoch 00031: val_loss did not improve from 0.42289
# Epoch 32/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0969 - accuracy: 0.9890 - val_loss: 0.4199 - val_accuracy: 0.8659
#
# Epoch 00032: val_loss improved from 0.42289 to 0.41986, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 33/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0913 - accuracy: 0.9896 - val_loss: 0.4206 - val_accuracy: 0.8599
#
# Epoch 00033: val_loss did not improve from 0.41986
# Epoch 34/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0881 - accuracy: 0.9921 - val_loss: 0.4277 - val_accuracy: 0.8671
#
# Epoch 00034: val_loss did not improve from 0.41986
# Epoch 35/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0856 - accuracy: 0.9900 - val_loss: 0.4237 - val_accuracy: 0.8695
#
# Epoch 00035: val_loss did not improve from 0.41986
# Epoch 36/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0802 - accuracy: 0.9932 - val_loss: 0.4217 - val_accuracy: 0.8635
# Epoch 00036: val_loss did not improve from 0.41986
# Epoch 37/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0757 - accuracy: 0.9942 - val_loss: 0.4216 - val_accuracy: 0.8647
#
# Epoch 00037: val_loss did not improve from 0.41986
# Epoch 38/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0786 - accuracy: 0.9903 - val_loss: 0.4178 - val_accuracy: 0.8635
#
# Epoch 00038: val_loss improved from 0.41986 to 0.41776, saving model to saved_models/weights.best.Xception.hdf5
# Epoch 39/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0710 - accuracy: 0.9954 - val_loss: 0.4214 - val_accuracy: 0.8671
#
# Epoch 00039: val_loss did not improve from 0.41776
# Epoch 40/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0746 - accuracy: 0.9923 - val_loss: 0.4208 - val_accuracy: 0.8695
#
# Epoch 00040: val_loss did not improve from 0.41776
# Epoch 41/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0712 - accuracy: 0.9924 - val_loss: 0.4342 - val_accuracy: 0.8659
#
# Epoch 00041: val_loss did not improve from 0.41776
# Epoch 42/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0716 - accuracy: 0.9933 - val_loss: 0.4313 - val_accuracy: 0.8659
#
# Epoch 00042: val_loss did not improve from 0.41776
# Epoch 43/60
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0695 - accuracy: 0.9938 - val_loss: 0.4238 - val_accuracy: 0.8659
#
# Epoch 00043: val_loss did not improve from 0.41776
# Epoch 44/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0626 - accuracy: 0.9944 - val_loss: 0.4226 - val_accuracy: 0.8671
#
# Epoch 00044: val_loss did not improve from 0.41776
# Epoch 45/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0619 - accuracy: 0.9951 - val_loss: 0.4218 - val_accuracy: 0.8659
#
# Epoch 00045: val_loss did not improve from 0.41776
# Epoch 46/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0605 - accuracy: 0.9957 - val_loss: 0.4225 - val_accuracy: 0.8683
#
# Epoch 00046: val_loss did not improve from 0.41776
# Epoch 47/60
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0616 - accuracy: 0.9935 - val_loss: 0.4211 - val_accuracy: 0.8611
#
# Epoch 00047: val_loss did not improve from 0.41776
# Epoch 48/60
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0606 - accuracy: 0.9925 - val_loss: 0.4283 - val_accuracy: 0.8683
#
# Epoch 00048: val_loss did not improve from 0.41776
# Epoch 49/60
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0578 - accuracy: 0.9949 - val_loss: 0.4265 - val_accuracy: 0.8671
#
# Epoch 00049: val_loss did not improve from 0.41776
# Epoch 50/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0562 - accuracy: 0.9962 - val_loss: 0.4287 - val_accuracy: 0.8635
#
# Epoch 00050: val_loss did not improve from 0.41776
# Epoch 51/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0548 - accuracy: 0.9958 - val_loss: 0.4248 - val_accuracy: 0.8659
#
# Epoch 00051: val_loss did not improve from 0.41776
# Epoch 52/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0521 - accuracy: 0.9968 - val_loss: 0.4295 - val_accuracy: 0.8647
#
# Epoch 00052: val_loss did not improve from 0.41776
# Epoch 53/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0508 - accuracy: 0.9947 - val_loss: 0.4371 - val_accuracy: 0.8623
#
# Epoch 00053: val_loss did not improve from 0.41776
# Epoch 54/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0526 - accuracy: 0.9941 - val_loss: 0.4333 - val_accuracy: 0.8647
#
# Epoch 00054: val_loss did not improve from 0.41776
# Epoch 55/60
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0528 - accuracy: 0.9950 - val_loss: 0.4355 - val_accuracy: 0.8623
#
# Epoch 00055: val_loss did not improve from 0.41776
# Epoch 56/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0486 - accuracy: 0.9963 - val_loss: 0.4325 - val_accuracy: 0.8611
#
# Epoch 00056: val_loss did not improve from 0.41776
# Epoch 57/60
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0474 - accuracy: 0.9969 - val_loss: 0.4311 - val_accuracy: 0.8611
#
# Epoch 00057: val_loss did not improve from 0.41776
# Epoch 58/60
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0450 - accuracy: 0.9978 - val_loss: 0.4319 - val_accuracy: 0.8623
#
# Epoch 00058: val_loss did not improve from 0.41776
# Epoch 59/60
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0458 - accuracy: 0.9969 - val_loss: 0.4336 - val_accuracy: 0.8611
#
# Epoch 00059: val_loss did not improve from 0.41776
# Epoch 60/60
# 14/14 [==============================] - 1s 46ms/step - loss: 0.0453 - accuracy: 0.9959 - val_loss: 0.4326 - val_accuracy: 0.8587
#
# Epoch 00060: val_loss did not improve from 0.41776
# CPU times: user 4min 10s, sys: 28.5 s, total: 4min 38s
# Wall time: 52.5 s

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
def load_weights(model):
    return model.load_weights('saved_models/weights.best.Xception.hdf5')

Xception_model = create_model()
load_weights(Xception_model)

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
# %%time
predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]
test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)

print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 86.2440%
# CPU times: user 20.5 s, sys: 377 ms, total: 20.8 s
# Wall time: 20.3 s

# %% [markdown]
# ### Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
from keras.applications.xception import Xception, preprocess_input
model = Xception(weights='imagenet', include_top=False)

def Xception_predict_breed(img_path):
    bottleneck_feature = model.predict(preprocess_input(path_to_tensor(img_path)))
    predicted_vector = Xception_model.predict(bottleneck_feature)
    return dog_names[np.argmax(predicted_vector)].split('/')[1]

# %%
predictions = [Xception_predict_breed(x) for x in train_files[:20]]

# %%
for idx, img in enumerate(train_files[:20]):
    breed = img.split('/')[3]
    
    predicted = predictions[idx]
    prediction = 'OK'
    
    if predicted != breed:
        prediction = 'NOK'
    
    print(f'{breed} -> {predicted}: {prediction}')
# Out:
# 095.Kuvasz -> 095.Kuvasz: OK
# 057.Dalmatian -> 057.Dalmatian: OK
# 088.Irish_water_spaniel -> 088.Irish_water_spaniel: OK
# 008.American_staffordshire_terrier -> 008.American_staffordshire_terrier: OK
# 008.American_staffordshire_terrier -> 008.American_staffordshire_terrier: OK
# 063.English_springer_spaniel -> 063.English_springer_spaniel: OK
# 054.Collie -> 054.Collie: OK
# 119.Petit_basset_griffon_vendeen -> 119.Petit_basset_griffon_vendeen: OK
# 009.American_water_spaniel -> 009.American_water_spaniel: OK
# 081.Greyhound -> 081.Greyhound: OK
# 012.Australian_shepherd -> 012.Australian_shepherd: OK
# 071.German_shepherd_dog -> 071.German_shepherd_dog: OK
# 015.Basset_hound -> 015.Basset_hound: OK
# 053.Cocker_spaniel -> 053.Cocker_spaniel: OK
# 099.Lhasa_apso -> 099.Lhasa_apso: OK
# 009.American_water_spaniel -> 009.American_water_spaniel: OK
# 056.Dachshund -> 056.Dachshund: OK
# 082.Havanese -> 082.Havanese: OK
# 117.Pekingese -> 117.Pekingese: OK
# 051.Chow_chow -> 051.Chow_chow: OK

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### Write your Algorithm

# %%
def predict(img: str) -> str:
    if dog_detector(img) or face_detector(img):
        return f"This photo looks like an {Xception_predict_breed(img).split('.')[1]}"
    
    return "Error: It is not a dog or a human face"

predict('images/sample_human_2.png')
# Out:
# 'This photo looks like an Dachshund'

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
from IPython.core.display import display, HTML

content = '<div>'

for i in range(7):
    img = f'./images/test/photo{i + 1}.jpg'
    content +=  f'<div><img src="{img}?42e" height="200" width="200"/><p>photo {i + 1}: {predict(img)}</p></div>'

content += '</div>'
display(HTML(content))
# Out:
# <div><div><img src="./images/test/photo1.jpg?42e" height="200" width="200"/><p>photo 1: This photo looks like an Dachshund</p></div><div><img src="./images/test/photo2.jpg?42e" height="200" width="200"/><p>photo 2: This photo looks like an Bulldog</p></div><div><img src="./images/test/photo3.jpg?42e" height="200" width="200"/><p>photo 3: This photo looks like an Belgian_sheepdog</p></div><div><img src="./images/test/photo4.jpg?42e" height="200" width="200"/><p>photo 4: This photo looks like an Dachshund</p></div><div><img src="./images/test/photo5.jpg?42e" height="200" width="200"/><p>photo 5: This photo looks like an Dalmatian</p></div><div><img src="./images/test/photo6.jpg?42e" height="200" width="200"/><p>photo 6: This photo looks like an Chinese_shar-pei</p></div><div><img src="./images/test/photo7.jpg?42e" height="200" width="200"/><p>photo 7: This photo looks like an Dachshund</p></div></div>

# %% [markdown]
# The model looks nice and I had a lot of fun doing. There is a lot of things to improve but given the scope and simplicity, it works better than I expected. However, there some potential issues:
#
# - it looks the model has some bias in classifying humans as `Dachshund`
# - the model classified a fake dog (photo 4) as a real dog. I liked it but it should not as it is not a dog or human
#
# Possible improvements
#
# - Analyze and confirm if we have a bias to classify photos as `Dachshund`. If it is the case, re-balance the training set
# - Training the model with more data and measure the accuracy. Currently is ~ 86%
# - In some tests, I noticed the model has problems to classify photos where we have objects close to the dog or human
